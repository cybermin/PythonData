# %%
import pandas as pd

# %%
data= pd.read_csv('출신지역.csv', engine='python')

# %%
data
# Out:
#                  지역
# 0         경상남도 거제시
# 1         경상남도 거제시
# 2         경상남도 거제시
# 3         경상남도 거제시
# 4         경상남도 거제시
# 5             부산광역시
# 6             부산광역시
# 7             부산광역시
# 8          경상남도 고성군
# 9          경상남도 김해시
# 10         경상남도 김해시
# 11        경상남도 김해시
# 12        경상남도 김해시
# 13        경상남도 김해시
# 14            부산광역시
# 15            부산광역시
# 16  경상남도 창원시 마산회원구
# 17           울산광역시
# 18            울산광역시
# 19           울산광역시
# 20         경상남도 밀양시
# 21            부산광역시
# 22           울산광역시
# 23        경상남도 양산시
# 24           부산광역시
# 25           부산광역시
# 26           부산광역시
# 27           부산광역시
# 28        경상남도 양산시
# 29            대구광역시
# ..              ...
# 34           울산광역시
# 35            울산광역시
# 36        경상남도 양산시
# 37        경상남도 양산시
# 38         경상남도 양산시
# 39         경상남도 거제시
# 40        울산광역시 울주군
# 41        울산광역시 울주군
# 42          경기도 용인시
# 43           울산광역시
# 44           울산광역시
# 45        경상북도 구미시
# 46        경상남도 김해시
# 47        경상남도 창원시
# ...

# %%
data2 = data['지역'].map(lambda x : len(x))

# %%
data3 = data['지역'].map(lambda x : x[:5])

# %%
data['지역2'] = data['지역'].apply(lambda x : x[:5])

# %%
dic = {'대구광역시':5,'부산광역시':10}
data['지역3'] = data['지역2'].map(dic )

# %%
data['지역2'] = data['지역2'].replace(dic )

# %%
data
# Out:
#                  지역    지역2   지역3
# 0         경상남도 거제시   경상남도    NaN
# 1         경상남도 거제시   경상남도    NaN
# 2         경상남도 거제시   경상남도    NaN
# 3         경상남도 거제시   경상남도    NaN
# 4         경상남도 거제시   경상남도    NaN
# 5             부산광역시     10  10.0
# 6             부산광역시     10  10.0
# 7             부산광역시     10  10.0
# 8          경상남도 고성군  경상남도    NaN
# 9          경상남도 김해시  경상남도    NaN
# 10         경상남도 김해시  경상남도    NaN
# 11        경상남도 김해시   경상남도    NaN
# 12        경상남도 김해시   경상남도    NaN
# 13        경상남도 김해시   경상남도    NaN
# 14            부산광역시     10  10.0
# 15            부산광역시     10  10.0
# 16  경상남도 창원시 마산회원구   경상남도    NaN
# 17           울산광역시   울산광역시   NaN
# 18            울산광역시  울산광역시   NaN
# 19           울산광역시   울산광역시   NaN
# 20         경상남도 밀양시  경상남도    NaN
# 21            부산광역시     10  10.0
# 22           울산광역시   울산광역시   NaN
# 23        경상남도 양산시   경상남도    NaN
# 24           부산광역시      10  10.0
# 25           부산광역시      10  10.0
# 26           부산광역시      10  10.0
# ...

# %%
ap = data['지역'].str.split(' ')
ap
# Out:
# 0            [경상남도, 거제시, ]
# 1            [경상남도, 거제시, ]
# 2            [경상남도, 거제시, ]
# 3            [경상남도, 거제시, ]
# 4            [경상남도, 거제시, ]
# 5                  [부산광역시]
# 6                  [부산광역시]
# 7                  [부산광역시]
# 8              [경상남도, 고성군]
# 9              [경상남도, 김해시]
# 10             [경상남도, 김해시]
# 11           [경상남도, 김해시, ]
# 12           [경상남도, 김해시, ]
# 13           [경상남도, 김해시, ]
# 14                 [부산광역시]
# 15                 [부산광역시]
# 16    [경상남도, 창원시, 마산회원구, ]
# 17               [울산광역시, ]
# 18                 [울산광역시]
# 19               [울산광역시, ]
# 20             [경상남도, 밀양시]
# 21                 [부산광역시]
# 22               [울산광역시, ]
# 23           [경상남도, 양산시, ]
# 24               [부산광역시, ]
# 25               [부산광역시, ]
# 26               [부산광역시, ]
# 27               [부산광역시, ]
# 28           [경상남도, 양산시, ]
# 29                 [대구광역시]
#               ...
# 34               [울산광역시, ]
# 35                 [울산광역시]
# 36           [경상남도, 양산시, ]
# ...

# %%
type(ap)
# Out:
# pandas.core.series.Series

# %%
ap = ap.apply(lambda x : pd.Series(x))
ap
# Out:
#         0    1      2    3
# 0    경상남도  거제시         NaN
# 1    경상남도  거제시         NaN
# 2    경상남도  거제시         NaN
# 3    경상남도  거제시         NaN
# 4    경상남도  거제시         NaN
# 5   부산광역시  NaN    NaN  NaN
# 6   부산광역시  NaN    NaN  NaN
# 7   부산광역시  NaN    NaN  NaN
# 8    경상남도  고성군    NaN  NaN
# 9    경상남도  김해시    NaN  NaN
# 10   경상남도  김해시    NaN  NaN
# 11   경상남도  김해시         NaN
# 12   경상남도  김해시         NaN
# 13   경상남도  김해시         NaN
# 14  부산광역시  NaN    NaN  NaN
# 15  부산광역시  NaN    NaN  NaN
# 16   경상남도  창원시  마산회원구
# 17  울산광역시         NaN  NaN
# 18  울산광역시  NaN    NaN  NaN
# 19  울산광역시         NaN  NaN
# 20   경상남도  밀양시    NaN  NaN
# 21  부산광역시  NaN    NaN  NaN
# 22  울산광역시         NaN  NaN
# 23   경상남도  양산시         NaN
# 24  부산광역시         NaN  NaN
# 25  부산광역시         NaN  NaN
# 26  부산광역시         NaN  NaN
# 27  부산광역시         NaN  NaN
# 28   경상남도  양산시         NaN
# 29  대구광역시  NaN    NaN  NaN
# ..    ...  ...    ...  ...
# 34  울산광역시         NaN  NaN
# 35  울산광역시  NaN    NaN  NaN
# ...

# %%
ap.isnull()
# Out:
#         0      1      2      3
# 0   False  False  False   True
# 1   False  False  False   True
# 2   False  False  False   True
# 3   False  False  False   True
# 4   False  False  False   True
# 5   False   True   True   True
# 6   False   True   True   True
# 7   False   True   True   True
# 8   False  False   True   True
# 9   False  False   True   True
# 10  False  False   True   True
# 11  False  False  False   True
# 12  False  False  False   True
# 13  False  False  False   True
# 14  False   True   True   True
# 15  False   True   True   True
# 16  False  False  False  False
# 17  False  False   True   True
# 18  False   True   True   True
# 19  False  False   True   True
# 20  False  False   True   True
# 21  False   True   True   True
# 22  False  False   True   True
# 23  False  False  False   True
# 24  False  False   True   True
# 25  False  False   True   True
# 26  False  False   True   True
# 27  False  False   True   True
# 28  False  False  False   True
# ...

# %%
ap.isna()
# Out:
#         0      1      2      3
# 0   False  False  False   True
# 1   False  False  False   True
# 2   False  False  False   True
# 3   False  False  False   True
# 4   False  False  False   True
# 5   False   True   True   True
# 6   False   True   True   True
# 7   False   True   True   True
# 8   False  False   True   True
# 9   False  False   True   True
# 10  False  False   True   True
# 11  False  False  False   True
# 12  False  False  False   True
# 13  False  False  False   True
# 14  False   True   True   True
# 15  False   True   True   True
# 16  False  False  False  False
# 17  False  False   True   True
# 18  False   True   True   True
# 19  False  False   True   True
# 20  False  False   True   True
# 21  False   True   True   True
# 22  False  False   True   True
# 23  False  False  False   True
# 24  False  False   True   True
# 25  False  False   True   True
# 26  False  False   True   True
# 27  False  False   True   True
# 28  False  False  False   True
# ...

# %%
ap.isnull().sum()
# Out:
# 0     0
# 1    19
# 2    44
# 3    63
# dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import missingno as msno

# %%
msno.matrix(ap)
plt.show()

# %%
msno.bar(ap)
plt.show()

# %%
ap2 = ap.dropna()

# %%
ap2
# Out:
#        0    1      2 3
# 16  경상남도  창원시  마산회원구

# %%
ap2 = ap.dropna(axis=1)

# %%
ap2
# Out:
#         0
# 0    경상남도
# 1    경상남도
# 2    경상남도
# 3    경상남도
# 4    경상남도
# 5   부산광역시
# 6   부산광역시
# 7   부산광역시
# 8    경상남도
# 9    경상남도
# 10   경상남도
# 11   경상남도
# 12   경상남도
# 13   경상남도
# 14  부산광역시
# 15  부산광역시
# 16   경상남도
# 17  울산광역시
# 18  울산광역시
# 19  울산광역시
# 20   경상남도
# 21  부산광역시
# 22  울산광역시
# 23   경상남도
# 24  부산광역시
# 25  부산광역시
# 26  부산광역시
# 27  부산광역시
# 28   경상남도
# 29  대구광역시
# ..    ...
# 34  울산광역시
# 35  울산광역시
# 36   경상남도
# 37   경상남도
# 38   경상남도
# 39   경상남도
# 40  울산광역시
# 41  울산광역시
# 42    경기도
# 43  울산광역시
# 44  울산광역시
# 45   경상북도
# 46   경상남도
# 47   경상남도
# 48   경상남도
# 49   경상남도
# 50   경상남도
# 51   경산남도
# 52   경상남도
# 53   경상남도
# 54   경상북도
# 55  부산광역시
# 56  부산광역시
# 57  부산광역시
# 58  부산광역시
# 59  울산광역시
# 60  울산광역시
# 61  울산광역시
# 62  울산광역시
# 63  울산광역시
#
# [64 rows x 1 columns]

# %%
ap2 = ap.dropna(thresh=44, axis=1)

# %%
ap2.columns = ['시','구']
ap2.head()
# Out:
#       시    구
# 0  경상남도  거제시
# 1  경상남도  거제시
# 2  경상남도  거제시
# 3  경상남도  거제시
# 4  경상남도  거제시

# %%
ap2['구'].fillna('*')
# Out:
# 0     거제시
# 1     거제시
# 2     거제시
# 3     거제시
# 4     거제시
# 5       *
# 6       *
# 7       *
# 8     고성군
# 9     김해시
# 10    김해시
# 11    김해시
# 12    김해시
# 13    김해시
# 14      *
# 15      *
# 16    창원시
# 17
# 18      *
# 19
# 20    밀양시
# 21      *
# 22
# 23    양산시
# 24
# 25
# 26
# 27
# 28    양산시
# 29      *
#      ...
# 34
# 35      *
# 36    양산시
# 37    양산시
# 38    양산시
# 39    거제시
# 40    울주군
# 41    울주군
# 42    용인시
# 43
# 44
# 45    구미시
# 46    김해시
# 47    창원시
# 48    창원시
# 49    창원시
# 50    창원시
# 51    창원시
# 52    창원시
# 53    통영시
# 54    포항시
# 55      *
# 56      *
# 57      *
# 58      *
# 59
# 60
# 61
# 62      *
# 63      *
# Name: 구, Length: 64, dtype: object

# %%
ap2
# Out:
#         시    구
# 0    경상남도  거제시
# 1    경상남도  거제시
# 2    경상남도  거제시
# 3    경상남도  거제시
# 4    경상남도  거제시
# 5   부산광역시    *
# 6   부산광역시    *
# 7   부산광역시    *
# 8    경상남도  고성군
# 9    경상남도  김해시
# 10   경상남도  김해시
# 11   경상남도  김해시
# 12   경상남도  김해시
# 13   경상남도  김해시
# 14  부산광역시    *
# 15  부산광역시    *
# 16   경상남도  창원시
# 17  울산광역시
# 18  울산광역시    *
# 19  울산광역시
# 20   경상남도  밀양시
# 21  부산광역시    *
# 22  울산광역시
# 23   경상남도  양산시
# 24  부산광역시
# 25  부산광역시
# 26  부산광역시
# 27  부산광역시
# 28   경상남도  양산시
# 29  대구광역시    *
# ..    ...  ...
# 34  울산광역시
# 35  울산광역시    *
# 36   경상남도  양산시
# 37   경상남도  양산시
# 38   경상남도  양산시
# 39   경상남도  거제시
# 40  울산광역시  울주군
# 41  울산광역시  울주군
# 42    경기도  용인시
# 43  울산광역시
# 44  울산광역시
# 45   경상북도  구미시
# 46   경상남도  김해시
# 47   경상남도  창원시
# 48   경상남도  창원시
# 49   경상남도  창원시
# 50   경상남도  창원시
# 51   경산남도  창원시
# 52   경상남도  창원시
# 53   경상남도  통영시
# 54   경상북도  포항시
# 55  부산광역시    *
# 56  부산광역시    *
# 57  부산광역시    *
# 58  부산광역시    *
# 59  울산광역시
# 60  울산광역시
# 61  울산광역시
# 62  울산광역시    *
# 63  울산광역시    *
#
# ...

# %%
ap2['지역'] = ap2.apply(lambda x: x.시 if x.구 == '*' or x.구 == '' else x.구, axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ap2
# Out:
#         시    구     지역
# 0    경상남도  거제시    거제시
# 1    경상남도  거제시    거제시
# 2    경상남도  거제시    거제시
# 3    경상남도  거제시    거제시
# 4    경상남도  거제시    거제시
# 5   부산광역시    *  부산광역시
# 6   부산광역시    *  부산광역시
# 7   부산광역시    *  부산광역시
# 8    경상남도  고성군    고성군
# 9    경상남도  김해시    김해시
# 10   경상남도  김해시    김해시
# 11   경상남도  김해시    김해시
# 12   경상남도  김해시    김해시
# 13   경상남도  김해시    김해시
# 14  부산광역시    *  부산광역시
# 15  부산광역시    *  부산광역시
# 16   경상남도  창원시    창원시
# 17  울산광역시       울산광역시
# 18  울산광역시    *  울산광역시
# 19  울산광역시       울산광역시
# 20   경상남도  밀양시    밀양시
# 21  부산광역시    *  부산광역시
# 22  울산광역시       울산광역시
# 23   경상남도  양산시    양산시
# 24  부산광역시       부산광역시
# 25  부산광역시       부산광역시
# 26  부산광역시       부산광역시
# 27  부산광역시       부산광역시
# 28   경상남도  양산시    양산시
# 29  대구광역시    *  대구광역시
# ..    ...  ...    ...
# 34  울산광역시       울산광역시
# 35  울산광역시    *  울산광역시
# 36   경상남도  양산시    양산시
# 37   경상남도  양산시    양산시
# 38   경상남도  양산시    양산시
# 39   경상남도  거제시    거제시
# 40  울산광역시  울주군    울주군
# 41  울산광역시  울주군    울주군
# 42    경기도  용인시    용인시
# ...

# %%
ap2g = ap2.groupby('지역')['시'].count()

# %%
ap2g
# Out:
# 지역
# 거제시       6
# 고성군       1
# 구미시       1
# 김해시       6
# 대구광역시     2
# 밀양시       1
# 부산광역시    14
# 양산시       5
# 용인시       1
# 울산광역시    16
# 울주군       2
# 창원시       7
# 통영시       1
# 포항시       1
# Name: 시, dtype: int64

# %%
type(ap2g)
# Out:
# pandas.core.series.Series

# %%
ap2g= pd.DataFrame(ap2g)
type(ap2g)
# Out:
# pandas.core.frame.DataFrame

# %%
ap2g
# Out:
#         시
# 지역
# 거제시     6
# 고성군     1
# 구미시     1
# 김해시     6
# 대구광역시   2
# 밀양시     1
# 부산광역시  14
# 양산시     5
# 용인시     1
# 울산광역시  16
# 울주군     2
# 창원시     7
# 통영시     1
# 포항시     1

# %%
ax = ap2g.plot(kind='bar', legend=False)
for p in ax.patches :
    l, bt, w, h = p.get_bbox().bounds
    ax.annotate(h, (l+ w/2, h*1.01), ha='center')

plt.title('지역별 지원자수')
plt.show()
