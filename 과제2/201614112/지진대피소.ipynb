# %%
import pandas as pd

# %%
df= pd.read_csv('전국지진해일대피소표준데이터.csv',engine='python')

# %%
df.head()
# Out:
#    지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분             소재지도로명주소  \
# 0   내수2근린공원     지진대피소     옥외대피소          공원      서울특별시 종로구 경희궁4길
# 1  대동세무고등학교     지진대피소     옥외대피소         운동장  서울특별시 종로구 계동길 84-10
# 2    대신고등학교     지진대피소     옥외대피소         운동장      서울특별시 종로구 사직로 9
# 3  덕성여자고등학교     지진대피소     옥외대피소         운동장   서울특별시 종로구 율곡로3길 50
# 4   덕성여자중학교     지진대피소     옥외대피소         운동장   서울특별시 종로구 율곡로3길 49
#
#               소재지지번주소         위도          경도  수용가능면적  최대수용인원수  ... 해발높이  \
# 0  서울특별시 종로구 내수동 73-3  37.572387  126.971583  2192.0    664.0  ...  NaN
# 1                 NaN  37.581920  126.987930  2000.0   1000.0  ...  NaN
# 2                 NaN  37.572915  126.961601  4663.0   1413.0  ...  NaN
# 3                 NaN  37.577918  126.982867  4180.0   1260.0  ...  NaN
# 4                 NaN  37.577945  126.981778  6701.0   2030.0  ...  NaN
#
#   지진대피안내표지판수 긴급대피장소안내표지판수 지진대피로안내표지판수  관리기관명      관리기관전화번호     데이터기준일자  \
# ...

# %%
df.columns
# Out:
# Index(['지진해일대피소명', '지진해일대피소구분', '지진해일대피소유형', '지진해일대피소유형구분', '소재지도로명주소',
#        '소재지지번주소', '위도', '경도', '수용가능면적', '최대수용인원수', '지진해일대피소운영상태',
#        '지진해일대피소전화번호', '부대편의시설', '주민대피지구명', '주민대피지구내가구수', '주민대피지구내거주인수',
#        '주민대피지구내재해약자수', '내진적용여부', '내진설계등급', '해안선이격거리', '해발높이', '지진대피안내표지판수',
#        '긴급대피장소안내표지판수', '지진대피로안내표지판수', '관리기관명', '관리기관전화번호', '데이터기준일자', '제공기관코드',
#        '제공기관명', 'Unnamed: 29'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9805 entries, 0 to 9804
# Data columns (total 30 columns):
# 지진해일대피소명        9805 non-null object
# 지진해일대피소구분       9805 non-null object
# 지진해일대피소유형       9805 non-null object
# 지진해일대피소유형구분     9805 non-null object
# 소재지도로명주소        9161 non-null object
# 소재지지번주소         4300 non-null object
# 위도              9714 non-null float64
# 경도              9715 non-null float64
# 수용가능면적          9805 non-null float64
# 최대수용인원수         9805 non-null float64
# 지진해일대피소운영상태     9805 non-null object
# 지진해일대피소전화번호     9805 non-null object
# 부대편의시설          444 non-null object
# 주민대피지구명         9805 non-null object
# 주민대피지구내가구수      527 non-null float64
# 주민대피지구내거주인수     433 non-null float64
# 주민대피지구내재해약자수    252 non-null float64
# 내진적용여부          9805 non-null object
# 내진설계등급          261 non-null object
# 해안선이격거리         920 non-null float64
# 해발높이            986 non-null float64
# 지진대피안내표지판수      2744 non-null float64
# ...

# %%
df.head()
# Out:
#    지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분             소재지도로명주소  \
# 0   내수2근린공원     지진대피소     옥외대피소          공원      서울특별시 종로구 경희궁4길
# 1  대동세무고등학교     지진대피소     옥외대피소         운동장  서울특별시 종로구 계동길 84-10
# 2    대신고등학교     지진대피소     옥외대피소         운동장      서울특별시 종로구 사직로 9
# 3  덕성여자고등학교     지진대피소     옥외대피소         운동장   서울특별시 종로구 율곡로3길 50
# 4   덕성여자중학교     지진대피소     옥외대피소         운동장   서울특별시 종로구 율곡로3길 49
#
#               소재지지번주소         위도          경도  수용가능면적  최대수용인원수  ... 해발높이  \
# 0  서울특별시 종로구 내수동 73-3  37.572387  126.971583  2192.0    664.0  ...  NaN
# 1                 NaN  37.581920  126.987930  2000.0   1000.0  ...  NaN
# 2                 NaN  37.572915  126.961601  4663.0   1413.0  ...  NaN
# 3                 NaN  37.577918  126.982867  4180.0   1260.0  ...  NaN
# 4                 NaN  37.577945  126.981778  6701.0   2030.0  ...  NaN
#
#   지진대피안내표지판수 긴급대피장소안내표지판수 지진대피로안내표지판수  관리기관명      관리기관전화번호     데이터기준일자  \
# ...

# %%
del df['Unnamed: 29']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9805 entries, 0 to 9804
# Data columns (total 29 columns):
# 지진해일대피소명        9805 non-null object
# 지진해일대피소구분       9805 non-null object
# 지진해일대피소유형       9805 non-null object
# 지진해일대피소유형구분     9805 non-null object
# 소재지도로명주소        9161 non-null object
# 소재지지번주소         4300 non-null object
# 위도              9714 non-null float64
# 경도              9715 non-null float64
# 수용가능면적          9805 non-null float64
# 최대수용인원수         9805 non-null float64
# 지진해일대피소운영상태     9805 non-null object
# 지진해일대피소전화번호     9805 non-null object
# 부대편의시설          444 non-null object
# 주민대피지구명         9805 non-null object
# 주민대피지구내가구수      527 non-null float64
# 주민대피지구내거주인수     433 non-null float64
# 주민대피지구내재해약자수    252 non-null float64
# 내진적용여부          9805 non-null object
# 내진설계등급          261 non-null object
# 해안선이격거리         920 non-null float64
# 해발높이            986 non-null float64
# 지진대피안내표지판수      2744 non-null float64
# ...

# %%
df.head()
# Out:
#    지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분             소재지도로명주소  \
# 0   내수2근린공원     지진대피소     옥외대피소          공원      서울특별시 종로구 경희궁4길
# 1  대동세무고등학교     지진대피소     옥외대피소         운동장  서울특별시 종로구 계동길 84-10
# 2    대신고등학교     지진대피소     옥외대피소         운동장      서울특별시 종로구 사직로 9
# 3  덕성여자고등학교     지진대피소     옥외대피소         운동장   서울특별시 종로구 율곡로3길 50
# 4   덕성여자중학교     지진대피소     옥외대피소         운동장   서울특별시 종로구 율곡로3길 49
#
#               소재지지번주소         위도          경도  수용가능면적  최대수용인원수  ... 해안선이격거리  \
# 0  서울특별시 종로구 내수동 73-3  37.572387  126.971583  2192.0    664.0  ...     NaN
# 1                 NaN  37.581920  126.987930  2000.0   1000.0  ...     NaN
# 2                 NaN  37.572915  126.961601  4663.0   1413.0  ...     NaN
# 3                 NaN  37.577918  126.982867  4180.0   1260.0  ...     NaN
# 4                 NaN  37.577945  126.981778  6701.0   2030.0  ...     NaN
#
#   해발높이 지진대피안내표지판수 긴급대피장소안내표지판수  지진대피로안내표지판수  관리기관명      관리기관전화번호     데이터기준일자  \
# ...

# %%
c= df.columns

# %%
c= list(c)

# %%
c
# Out:
# ['지진해일대피소명',
#  '지진해일대피소구분',
#  '지진해일대피소유형',
#  '지진해일대피소유형구분',
#  '소재지도로명주소',
#  '소재지지번주소',
#  '위도',
#  '경도',
#  '수용가능면적',
#  '최대수용인원수',
#  '지진해일대피소운영상태',
#  '지진해일대피소전화번호',
#  '부대편의시설',
#  '주민대피지구명',
#  '주민대피지구내가구수',
#  '주민대피지구내거주인수',
#  '주민대피지구내재해약자수',
#  '내진적용여부',
#  '내진설계등급',
#  '해안선이격거리',
#  '해발높이',
#  '지진대피안내표지판수',
#  '긴급대피장소안내표지판수',
#  '지진대피로안내표지판수',
#  '관리기관명',
#  '관리기관전화번호',
#  '데이터기준일자',
#  '제공기관코드',
#  '제공기관명']

# %%
c= [item.strip() for item in c]

# %%
df.columns= c
df.columns
# Out:
# Index(['지진해일대피소명', '지진해일대피소구분', '지진해일대피소유형', '지진해일대피소유형구분', '소재지도로명주소',
#        '소재지지번주소', '위도', '경도', '수용가능면적', '최대수용인원수', '지진해일대피소운영상태',
#        '지진해일대피소전화번호', '부대편의시설', '주민대피지구명', '주민대피지구내가구수', '주민대피지구내거주인수',
#        '주민대피지구내재해약자수', '내진적용여부', '내진설계등급', '해안선이격거리', '해발높이', '지진대피안내표지판수',
#        '긴급대피장소안내표지판수', '지진대피로안내표지판수', '관리기관명', '관리기관전화번호', '데이터기준일자', '제공기관코드',
#        '제공기관명'],
#       dtype='object')

# %%
df_1 = df[df['내진적용여부']=='적용']

# %%
df_1
# Out:
#          지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분  \
# 5664        주곡중학교     지진대피소     실내대피소          학교
# 5665       진접고등학교     지진대피소     실내대피소          학교
# 5673        양오중학교     지진대피소     실내대피소          학교
# 5674       양오초등학교     지진대피소     실내대피소          학교
# 5676        어람중학교     지진대피소     실내대피소          학교
# 7526       웅산초등학교     지진대피소     실내대피소          학교
# 7525        삽교중학교     지진대피소     실내대피소          학교
# 7524       보성초등학교     지진대피소     실내대피소          학교
# 7520   예산초등학교(강당)     지진대피소     실내대피소          학교
# 4089     서울문현초등학교     지진대피소     실내대피소          학교
# 4088     서울문정초등학교     지진대피소     실내대피소          학교
# 4087     서울문덕초등학교     지진대피소     실내대피소          학교
# 4086     서울개롱초등학교     지진대피소     실내대피소          학교
# 4085     서울가원초등학교     지진대피소     실내대피소          학교
# 4084       방산고등학교     지진대피소     실내대피소          학교
# 4083        문현중학교     지진대피소     실내대피소          학교
# 4082        가락중학교     지진대피소     실내대피소          학교
# 4080       동주초등학교     지진대피소     실내대피소          학교
# ...

# %%
df_o  = df[df['내진적용여부']=='적용']

# %%
df_x = df[df['내진적용여부']=='미적용']

# %%
df=df.sort_values(by='지진해일대피소유형구분',ascending=False)

# %%
df_o = df_o.sort_values(by='지진해일대피소유형구분',ascending=False)

# %%
df_x = df_x.sort_values(by='지진해일대피소유형구분',ascending=False)

# %%
df_o.tail()
# Out:
#      지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분               소재지도로명주소  \
# 174     능허대공원     지진대피소     옥외대피소          공원        인천광역시 연수구 독배로29
# 9101   새마을 공원     지진대피소     옥외대피소          공원   전라북도 고창군 고창읍 석교리 7-1
# 9065     월곡공원     지진대피소     옥외대피소          공원  전라북도 고창군 고창읍 월곡10길 29
# 182      용담공원     지진대피소     옥외대피소          공원        인천광역시 연수구 용담로61
# 7548     행동공원     지진대피소     옥외대피소          공원    전라남도 순천시 금곡길 20(행동)
#
#                     소재지지번주소         위도          경도    수용가능면적  최대수용인원수  ...  \
# 174   인천광역시 연수구 옥련1동 194-54  37.427629  126.655255    1642.0    498.0  ...
# 9101   전라북도 고창군 고창읍 석교리 7-1  35.441179  126.697931  110600.0  33515.0  ...
# 9065  전라북도 고창군 고창읍 월곡10길 29  35.436163  126.714032    1963.0   5948.0  ...
# 182       인천광역시 연수구 청학동 467  37.418579  126.674208   29854.0   9047.0  ...
# 7548       전라남도 순천시 행동 65-7  34.955067  127.482561    2000.0    606.0  ...
#
#      해안선이격거리  해발높이 지진대피안내표지판수 긴급대피장소안내표지판수  지진대피로안내표지판수       관리기관명  \
# ...

# %%
df_o_s=df_o[df_o['내진설계등급']=='특등급']

# %%
df_o_1=df_o[df_o['내진설계등급']=='1등급']

# %%
df_o_2=df_o[df_o['내진설계등급']=='2등급']

# %%
df_o_s
# Out:
#          지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분                  소재지도로명주소  \
# 2422       송현고등학교     지진대피소     실내대피소          학교  경기도 의정부시 민락동 735-4번지 민락동
# 2421       삼현초등학교     지진대피소     실내대피소          학교    경기도 의정부시 민락동 893번지 낙양동
# 2411    의정부호원초등학교     지진대피소     실내대피소          학교  경기도 의정부시 호원동 292-1번지 호원동
# 213   송도해수욕장공영주차장   지진해일대피소     실내대피소          기타    부산광역시 서구 암남공원로 25(암남동)
# 864        울산항만공사   지진해일대피소     옥외대피소          기타      울산광역시 남구 장생포 고래로 271
#
#                                소재지지번주소         위도          경도  수용가능면적  \
# 2422      경기도 의정부시 용민로 159, 민락동  (민락동)  37.743922  127.090837   750.0
# 2421       경기도 의정부시 송양로 87, 낙양동  (민락동)  37.751122  127.115782   496.0
# 2411  경기도 의정부시 전좌로156번길 20, 호원동  (호원동)  37.721949  127.041093   231.0
# 213                   부산광역시 서구 암남동 579  35.073722  129.013538  1088.5
# 864               울산광역시 남구 장생포 고래로 271  35.504897  129.382843   330.0
#
#       최대수용인원수  ... 해안선이격거리  해발높이 지진대피안내표지판수 긴급대피장소안내표지판수  지진대피로안내표지판수  \
# ...

# %%
len(df_o_1)
# Out:
# 206

# %%
len(df_o_2)
# Out:
# 14

# %%
df_o_sc_s =df_o_s[df_o_s['지진해일대피소유형구분']=='학교']

# %%
df_o_sc_1 =df_o_1[df_o_1['지진해일대피소유형구분']=='학교']

# %%
df_o_sc_2 =df_o_2[df_o_2['지진해일대피소유형구분']=='학교']

# %%
len(df_o[df_o['지진해일대피소유형구분']=='학교'])
# Out:
# 949

# %%
df_o_n =df_o[df_o['내진설계등급'].isnull()]

# %%
df=df.fillna(0)

# %%
df_sc= df_o[df_o['지진해일대피소유형구분']=='학교']

# %%
df_o_sc_n = df_sc[df_sc['내진설계등급']==0]

# %%
len(df_o_sc_n)
# Out:
# 917

# %%
len(df_sc)
# Out:
# 949

# %%
len(df_o_n)
# Out:
# 0

# %%
# Out:
# 7648    1등급
# 9635    1등급
# 9164    1등급
# 9165    1등급
# 9166    1등급
# 9167    1등급
# 9169    1등급
# 2252    1등급
# 9171    1등급
# 9174    1등급
# 9175    1등급
# 9176    1등급
# 9150    1등급
# 9185    1등급
# 9111    1등급
# 9107    1등급
# 9108    1등급
# 9113    1등급
# 9117    1등급
# 9118    1등급
# 9087    1등급
# 9074    1등급
# 9075    1등급
# 9076    1등급
# 9077    1등급
# 9078    1등급
# 9079    1등급
# 9104    1등급
# 9640    1등급
# 9183    1등급
#        ...
# 7529    NaN
# 7530    NaN
# 7531    NaN
# 7533    NaN
# 1890    NaN
# 7534    NaN
# 7536    NaN
# 7537    NaN
# 7538    NaN
# 7539    NaN
# 7548    NaN
# 1889    NaN
# 1891    NaN
# 7437    NaN
# 1893    NaN
# 7454    NaN
# 7455    NaN
# 7460    NaN
# 7464    NaN
# 7467    NaN
# 7468    NaN
# 7471    NaN
# 7472    NaN
# 7473    NaN
# 7474    NaN
# 1908    NaN
# 1901    NaN
# 1894    NaN
# 0       NaN
# 3029    NaN
# Name: 내진설계등급, Length: 9805, dtype: object

# %%
# Out:
#   File "<ipython-input-54-8e3486a45100>", line 1
#     ddd[!='nan']
#          ^
# SyntaxError: invalid syntax
